# %% [markdown]
# # 🧪 CAPTCHA Handling Tutorial - Learning Validation & Assessment
#
# This companion notebook provides **progressive learning validation** for the AgentCore Browser Tool + browser-use CAPTCHA handling tutorial. Use this to:
#
# - ✅ **Validate Section Completion**: Check that you've successfully completed each tutorial section
# - 🎯 **Assess Learning Progress**: Verify understanding of key integration concepts
# - 🔧 **Troubleshoot Issues**: Get automated diagnostics and solutions for common problems
# - 📊 **Track Mastery**: Monitor your progress through the comprehensive tutorial
#
# ## 📋 How to Use This Validation Notebook
#
# 1. **Complete a section** in the main tutorial notebook first
# 2. **Run the corresponding validation** in this notebook
# 3. **Review results** and address any issues identified
# 4. **Proceed to next section** once validation passes
#
# ## 🎯 Learning Objectives Validation
#
# This notebook validates that you've achieved the core learning objectives:
#
# - **Environment Setup**: Python 3.12, AWS credentials, dependencies
# - **AgentCore Integration**: Session management, enterprise features
# - **Hybrid Architecture**: AgentCore + browser-use coordination
# - **AI-Powered Analysis**: AWS Bedrock integration for CAPTCHA solving
# - **Production Readiness**: Error handling, monitoring, best practices
#
# ## 📊 Validation Summary Overview
#
# ### 🎯 Validation Scope
# This notebook provides comprehensive validation across **6 tutorial sections**:
#
# | Section | Validation Focus | Key Checks | Expected Files |
# |---------|------------------|------------|----------------|
# | **1** | Environment Setup | Python 3.12+, AWS, Dependencies | `requirements.txt` |
# | **2** | AgentCore Integration | Session management files | `agentcore_session_manager.py` |
# | **3** | Hybrid Architecture | Integration patterns | `hybrid_captcha_solver.py` |
# | **4** | AI Analysis | Bedrock client, AI files | `bedrock_captcha_analyzer.py` |
# | **5** | Production Workflows | Error handling, monitoring | `error_handler.py` |
# | **6** | Complete Integration | End-to-end examples | `complete_captcha_solution.py` |
#
# ### 🔍 Validation Features
# - **Automated Checks**: Environment, dependencies, file existence, code patterns
# - **Rich Reporting**: Color-coded results with detailed feedback
# - **Progress Tracking**: Section-by-section completion monitoring
# - **Troubleshooting**: Specific suggestions for resolving issues
# - **Overall Assessment**: Comprehensive completion summary
#
# ### 📈 Success Metrics
# - **100% Completion**: All sections validated successfully
# - **70-99% Completion**: Good progress, minor issues to resolve
# - **<70% Completion**: Significant work needed, review tutorial sections
#
# ### 🚀 Quick Start
# 1. **Run Individual Sections**: Execute validation cells for completed tutorial sections
# 2. **Run Complete Validation**: Use the final cell for comprehensive assessment
# 3. **Review Results**: Check color-coded feedback and suggestions
# 4. **Address Issues**: Follow provided suggestions to resolve problems
# 5. **Re-validate**: Run validation again after making fixes
#
# ---

# %%
#!/usr/bin/env python3
"""
CAPTCHA Handling Tutorial - Validation Framework

This notebook provides comprehensive validation for the AgentCore Browser Tool + browser-use
CAPTCHA handling tutorial, ensuring students have successfully completed each section
and mastered the key integration concepts.

Requirements: 6.1, 6.2, 6.4
"""

import sys
import os
import json
import asyncio
import subprocess
from pathlib import Path
from typing import Dict, List, Any, Optional, Tuple
from dataclasses import dataclass
from datetime import datetime

# Rich console for beautiful output
from rich.console import Console
from rich.table import Table
from rich.panel import Panel
from rich.progress import Progress, SpinnerColumn, TextColumn
from rich.tree import Tree
from rich.syntax import Syntax

# Add current directory to path for imports
sys.path.append(os.getcwd())

console = Console()
console.print("[bold green]✅ Validation Framework Initialized[/bold green]")

# %%
@dataclass
class ValidationResult:
    """Result of a validation check"""
    section: str
    check_name: str
    passed: bool
    message: str
    details: Optional[Dict[str, Any]] = None
    suggestions: Optional[List[str]] = None

@dataclass
class SectionProgress:
    """Progress tracking for a tutorial section"""
    section_number: int
    section_name: str
    completed: bool
    validation_results: List[ValidationResult]
    completion_percentage: float
    key_concepts_mastered: List[str]
    issues_found: List[str]

class TutorialValidator:
    """Main validation class for the CAPTCHA handling tutorial"""
    
    def __init__(self):
        self.console = Console()
        self.tutorial_sections = {
            1: "Prerequisites and Environment Setup",
            2: "AgentCore Browser Tool Session Management",
            3: "Hybrid browser-use + AgentCore Integration",
            4: "AWS Bedrock AI Analysis Integration",
            5: "Production Workflows and Error Handling",
            6: "Complete Integration Examples and Best Practices"
        }
        self.validation_results = []
        
    def create_validation_result(self, section: str, check_name: str, 
                               passed: bool, message: str, 
                               details: Dict[str, Any] = None,
                               suggestions: List[str] = None) -> ValidationResult:
        """Create a validation result"""
        return ValidationResult(
            section=section,
            check_name=check_name,
            passed=passed,
            message=message,
            details=details or {},
            suggestions=suggestions or []
        )

# Initialize the validator
validator = TutorialValidator()
console.print("[bold green]✅ Validation Framework Ready[/bold green]")

# %% [markdown]
# ## 🔧 Section 1: Prerequisites and Environment Setup Validation
#
# This section validates that your development environment is properly configured with:
# - Python 3.12+
# - Required packages (boto3, browser-use, rich, etc.)
# - AWS credentials configuration
# - Development tools setup

# %%
async def validate_environment_setup() -> List[ValidationResult]:
    """Validate Section 1: Prerequisites and Environment Setup"""
    results = []
    section = "Section 1: Prerequisites and Environment Setup"
    
    # Check Python version
    python_version = sys.version_info
    if python_version >= (3, 12):
        results.append(validator.create_validation_result(
            section, "Python Version", True,
            f"✅ Python {python_version.major}.{python_version.minor} detected"
        ))
    else:
        results.append(validator.create_validation_result(
            section, "Python Version", False,
            f"❌ Python {python_version.major}.{python_version.minor} found, requires 3.12+",
            suggestions=["Install Python 3.12 or higher", "Update your Python environment"]
        ))
    
    # Check required packages
    required_packages = [
        "boto3", "browser-use", "rich", "asyncio", "pathlib"
    ]
    
    for package in required_packages:
        try:
            __import__(package.replace("-", "_"))
            results.append(validator.create_validation_result(
                section, f"Package: {package}", True,
                f"✅ {package} is installed"
            ))
        except ImportError:
            results.append(validator.create_validation_result(
                section, f"Package: {package}", False,
                f"❌ {package} is not installed",
                suggestions=[f"Install {package} using: pip install {package}"]
            ))
    
    # Check AWS credentials
    try:
        import boto3
        session = boto3.Session()
        credentials = session.get_credentials()
        if credentials:
            results.append(validator.create_validation_result(
                section, "AWS Credentials", True,
                "✅ AWS credentials are configured"
            ))
        else:
            results.append(validator.create_validation_result(
                section, "AWS Credentials", False,
                "❌ AWS credentials not found",
                suggestions=[
                    "Configure AWS credentials using aws configure",
                    "Set AWS_ACCESS_KEY_ID and AWS_SECRET_ACCESS_KEY environment variables",
                    "Use IAM roles if running on EC2"
                ]
            ))
    except Exception as e:
        results.append(validator.create_validation_result(
            section, "AWS Credentials", False,
            f"❌ Error checking AWS credentials: {str(e)}"
        ))
    
    return results

# Run Section 1 validation
section1_results = await validate_environment_setup()
validator.display_validation_results(section1_results)

# %% [markdown]
# ## 🔗 Section 2: AgentCore Browser Tool Session Management Validation
#
# This section validates your AgentCore integration setup:
# - Session management implementation
# - Browser tool configuration
# - Enterprise features setup

# %%
async def validate_agentcore_integration() -> List[ValidationResult]:
    """Validate Section 2: AgentCore Browser Tool Session Management"""
    results = []
    section = "Section 2: AgentCore Browser Tool Session Management"
    
    # Check if AgentCore session management code exists
    session_files = [
        "agentcore_session_manager.py",
        "browser_session_handler.py"
    ]
    
    for file_name in session_files:
        file_path = Path(file_name)
        if file_path.exists():
            results.append(validator.create_validation_result(
                section, f"File: {file_name}", True,
                f"✅ {file_name} exists"
            ))
        else:
            results.append(validator.create_validation_result(
                section, f"File: {file_name}", False,
                f"❌ {file_name} not found",
                suggestions=[f"Create {file_name} as shown in the tutorial"]
            ))
    
    return results

# Run Section 2 validation
section2_results = await validate_agentcore_integration()
validator.display_validation_results(section2_results)

# %% [markdown]
# ## 🔄 Section 3: Hybrid browser-use + AgentCore Integration Validation
#
# This section validates the hybrid architecture implementation:
# - browser-use integration
# - AgentCore coordination
# - Hybrid workflow patterns

# %%
async def validate_hybrid_integration() -> List[ValidationResult]:
    """Validate Section 3: Hybrid browser-use + AgentCore Integration"""
    results = []
    section = "Section 3: Hybrid browser-use + AgentCore Integration"
    
    # Check for hybrid integration files
    integration_files = [
        "hybrid_captcha_solver.py",
        "browser_agentcore_coordinator.py"
    ]
    
    for file_name in integration_files:
        file_path = Path(file_name)
        if file_path.exists():
            results.append(validator.create_validation_result(
                section, f"File: {file_name}", True,
                f"✅ {file_name} exists"
            ))
            
            # Check file content for key integration patterns
            try:
                with open(file_path, 'r') as f:
                    content = f.read()
                    
                key_patterns = [
                    "browser-use",
                    "AgentCore",
                    "async def",
                    "captcha"
                ]
                
                for pattern in key_patterns:
                    if pattern in content:
                        results.append(validator.create_validation_result(
                            section, f"Pattern: {pattern} in {file_name}", True,
                            f"✅ Found {pattern} integration pattern"
                        ))
                    else:
                        results.append(validator.create_validation_result(
                            section, f"Pattern: {pattern} in {file_name}", False,
                            f"❌ Missing {pattern} integration pattern",
                            suggestions=[f"Add {pattern} integration as shown in tutorial"]
                        ))
                        
            except Exception as e:
                results.append(validator.create_validation_result(
                    section, f"Content Check: {file_name}", False,
                    f"❌ Error reading {file_name}: {str(e)}"
                ))
        else:
            results.append(validator.create_validation_result(
                section, f"File: {file_name}", False,
                f"❌ {file_name} not found",
                suggestions=[f"Create {file_name} as shown in the tutorial"]
            ))
    
    return results

# Run Section 3 validation
section3_results = await validate_hybrid_integration()
validator.display_validation_results(section3_results)

# %% [markdown]
# ## 🤖 Section 4: AWS Bedrock AI Analysis Integration Validation
#
# This section validates AI-powered CAPTCHA analysis:
# - Bedrock client configuration
# - AI vision processing
# - CAPTCHA analysis workflows

# %%
async def validate_bedrock_integration() -> List[ValidationResult]:
    """Validate Section 4: AWS Bedrock AI Analysis Integration"""
    results = []
    section = "Section 4: AWS Bedrock AI Analysis Integration"
    
    # Check Bedrock client initialization
    try:
        import boto3
        bedrock_client = boto3.client('bedrock-runtime', region_name='us-east-1')
        results.append(validator.create_validation_result(
            section, "Bedrock Client", True,
            "✅ Bedrock client can be initialized"
        ))
    except Exception as e:
        results.append(validator.create_validation_result(
            section, "Bedrock Client", False,
            f"❌ Error initializing Bedrock client: {str(e)}",
            suggestions=[
                "Check AWS credentials",
                "Verify Bedrock service availability in your region",
                "Ensure proper IAM permissions for Bedrock"
            ]
        ))
    
    # Check for AI analysis files
    ai_files = [
        "bedrock_captcha_analyzer.py",
        "ai_vision_processor.py"
    ]
    
    for file_name in ai_files:
        file_path = Path(file_name)
        if file_path.exists():
            results.append(validator.create_validation_result(
                section, f"File: {file_name}", True,
                f"✅ {file_name} exists"
            ))
        else:
            results.append(validator.create_validation_result(
                section, f"File: {file_name}", False,
                f"❌ {file_name} not found",
                suggestions=[f"Create {file_name} as shown in the tutorial"]
            ))
    
    return results

# Run Section 4 validation
section4_results = await validate_bedrock_integration()
validator.display_validation_results(section4_results)

# %% [markdown]
# ## 🏭 Section 5: Production Workflows and Error Handling Validation
#
# This section validates production-ready implementation:
# - Error handling mechanisms
# - Monitoring and logging
# - Production configuration

# %%
async def validate_production_workflows() -> List[ValidationResult]:
    """Validate Section 5: Production Workflows and Error Handling"""
    results = []
    section = "Section 5: Production Workflows and Error Handling"
    
    # Check for production-ready files
    production_files = [
        "error_handler.py",
        "monitoring_setup.py",
        "production_config.py"
    ]
    
    for file_name in production_files:
        file_path = Path(file_name)
        if file_path.exists():
            results.append(validator.create_validation_result(
                section, f"File: {file_name}", True,
                f"✅ {file_name} exists"
            ))
        else:
            results.append(validator.create_validation_result(
                section, f"File: {file_name}", False,
                f"❌ {file_name} not found",
                suggestions=[f"Create {file_name} as shown in the tutorial"]
            ))
    
    return results

# Run Section 5 validation
section5_results = await validate_production_workflows()
validator.display_validation_results(section5_results)

# %% [markdown]
# ## 🎯 Section 6: Complete Integration Examples and Best Practices Validation
#
# This section validates the complete integration:
# - End-to-end examples
# - Best practices implementation
# - Integration testing

# %%
async def validate_complete_integration() -> List[ValidationResult]:
    """Validate Section 6: Complete Integration Examples and Best Practices"""
    results = []
    section = "Section 6: Complete Integration Examples and Best Practices"
    
    # Check for complete integration examples
    example_files = [
        "complete_captcha_solution.py",
        "best_practices_demo.py",
        "integration_tests.py"
    ]
    
    for file_name in example_files:
        file_path = Path(file_name)
        if file_path.exists():
            results.append(validator.create_validation_result(
                section, f"File: {file_name}", True,
                f"✅ {file_name} exists"
            ))
        else:
            results.append(validator.create_validation_result(
                section, f"File: {file_name}", False,
                f"❌ {file_name} not found",
                suggestions=[f"Create {file_name} as shown in the tutorial"]
            ))
    
    return results

# Run Section 6 validation
section6_results = await validate_complete_integration()
validator.display_validation_results(section6_results)

# %% [markdown]
# ## 🎉 Complete Tutorial Validation
#
# Run this cell to perform a comprehensive validation of all tutorial sections and get an overall completion report.

# %%
# Add display method to validator class
def display_validation_results(self, results: List[ValidationResult]):
    """Display validation results in a beautiful format"""
    
    # Group results by section
    sections = {}
    for result in results:
        if result.section not in sections:
            sections[result.section] = []
        sections[result.section].append(result)
    
    # Display each section
    for section_name, section_results in sections.items():
        
        # Calculate section statistics
        total_checks = len(section_results)
        passed_checks = sum(1 for r in section_results if r.passed)
        completion_percentage = (passed_checks / total_checks) * 100 if total_checks > 0 else 0
        
        # Create section panel
        status_color = "green" if completion_percentage == 100 else "yellow" if completion_percentage >= 50 else "red"
        
        panel_content = f"[bold]{section_name}[/bold]\n"
        panel_content += f"Progress: {passed_checks}/{total_checks} checks passed ({completion_percentage:.1f}%)\n\n"
        
        # Add individual check results
        for result in section_results:
            status_icon = "✅" if result.passed else "❌"
            panel_content += f"{status_icon} {result.check_name}: {result.message}\n"
            
            if result.suggestions:
                panel_content += "   💡 Suggestions:\n"
                for suggestion in result.suggestions:
                    panel_content += f"      • {suggestion}\n"
                panel_content += "\n"
        
        self.console.print(Panel(
            panel_content.strip(),
            title=f"[bold {status_color}]{section_name}[/bold {status_color}]",
            border_style=status_color
        ))
        self.console.print()

# Add the method to the validator instance
validator.display_validation_results = display_validation_results.__get__(validator, TutorialValidator)

async def run_full_validation():
    """Run complete validation for all tutorial sections"""
    
    console.print(Panel(
        "[bold blue]🧪 CAPTCHA Handling Tutorial - Complete Validation[/bold blue]\n\n"
        "Running comprehensive validation across all tutorial sections...",
        title="[bold blue]Validation Started[/bold blue]",
        border_style="blue"
    ))
    
    all_results = []
    
    # Run all validation sections
    validation_functions = [
        validate_environment_setup,
        validate_agentcore_integration,
        validate_hybrid_integration,
        validate_bedrock_integration,
        validate_production_workflows,
        validate_complete_integration
    ]
    
    with Progress(
        SpinnerColumn(),
        TextColumn("[progress.description]{task.description}"),
        console=console
    ) as progress:
        
        for i, validation_func in enumerate(validation_functions, 1):
            task = progress.add_task(f"Validating Section {i}...", total=None)
            
            try:
                results = await validation_func()
                all_results.extend(results)
                progress.update(task, description=f"✅ Section {i} validated")
            except Exception as e:
                console.print(f"[red]❌ Error validating section {i}: {str(e)}[/red]")
                progress.update(task, description=f"❌ Section {i} failed")
            
            progress.remove_task(task)
    
    # Display results
    validator.display_validation_results(all_results)
    
    # Generate summary
    total_checks = len(all_results)
    passed_checks = sum(1 for r in all_results if r.passed)
    overall_percentage = (passed_checks / total_checks) * 100 if total_checks > 0 else 0
    
    summary_color = "green" if overall_percentage == 100 else "yellow" if overall_percentage >= 70 else "red"
    
    console.print(Panel(
        f"[bold]Overall Tutorial Completion: {passed_checks}/{total_checks} ({overall_percentage:.1f}%)[/bold]\n\n"
        f"{'🎉 Congratulations! Tutorial completed successfully!' if overall_percentage == 100 else '📚 Continue working through the tutorial sections above.'}\n\n"
        f"Timestamp: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}",
        title=f"[bold {summary_color}]Validation Summary[/bold {summary_color}]",
        border_style=summary_color
    ))

# Run the complete validation
await run_full_validation()

# %% [markdown]
# ---
#
# # 📊 Validation Summary & Next Steps
#
# ## 🎯 Understanding Your Validation Results
#
# ### 🟢 Green Results (100% Completion)
# **Congratulations!** You've successfully completed all tutorial sections. Your environment is properly configured and all required components are in place.
#
# **Next Steps:**
# - ✅ **Ready for Production**: Your setup is enterprise-ready
# - 🚀 **Advanced Exploration**: Try custom implementations and optimizations
# - 📚 **Knowledge Sharing**: Document your learnings for your team
# - 🔄 **Continuous Learning**: Explore advanced CAPTCHA handling scenarios
#
# ### 🟡 Yellow Results (70-99% Completion)
# **Good Progress!** You've completed most sections with minor issues to resolve.
#
# **Action Items:**
# - 🔍 **Review Suggestions**: Follow the specific recommendations provided
# - 📝 **Complete Missing Files**: Create any missing implementation files
# - 🔧 **Fix Configuration**: Address environment or dependency issues
# - ✅ **Re-validate**: Run validation again after making fixes
#
# ### 🔴 Red Results (<70% Completion)
# **Needs Attention**: Significant work is needed to complete the tutorial.
#
# **Recommended Actions:**
# - 📖 **Review Tutorial**: Go back to incomplete sections in the main notebook
# - 🛠️ **Environment Setup**: Ensure Python 3.12+ and AWS credentials are configured
# - 📦 **Install Dependencies**: Run `pip install -r requirements.txt`
# - 🔄 **Step-by-Step**: Complete sections sequentially and validate each one
#
# ## 🛠️ Troubleshooting Common Issues
#
# ### 🐍 Python Environment Issues
# ```bash
# # Check Python version
# python --version
#
# # Install required packages
# pip install -r requirements.txt
#
# # Verify installations
# python -c "import boto3, rich; print('Dependencies OK')"
# ```
#
# ### ☁️ AWS Configuration Issues
# ```bash
# # Configure AWS credentials
# aws configure
#
# # Or set environment variables
# export AWS_ACCESS_KEY_ID=your_access_key
# export AWS_SECRET_ACCESS_KEY=your_secret_key
# export AWS_DEFAULT_REGION=us-east-1
#
# # Test AWS connection
# aws sts get-caller-identity
# ```
#
# ### 📁 Missing Files Issues
# - **Check File Paths**: Ensure you're running validation from the correct directory
# - **Create Missing Files**: Follow tutorial sections to create required implementation files
# - **Verify Imports**: Make sure all supporting Python modules are accessible
#
# ### 🔧 Integration Pattern Issues
# - **Review Code Patterns**: Check that your implementations include required integration patterns
# - **Follow Examples**: Use the provided example files as templates
# - **Test Incrementally**: Validate each section as you complete it
#
# ## 📈 Performance Optimization Tips
#
# ### 🚀 Speed Up Validation
# - **Run Individual Sections**: Validate sections as you complete them
# - **Cache Results**: Some validations cache results for faster re-runs
# - **Parallel Processing**: The validation framework uses async operations for efficiency
#
# ### 🎯 Focus Areas
# - **Critical Path**: Prioritize environment setup and core integration first
# - **Dependencies**: Resolve package and credential issues early
# - **File Structure**: Ensure proper file organization and naming
#
# ## 🎓 Learning Assessment
#
# ### 📊 Skill Progression Tracking
# Use validation results to track your learning progression:
#
# - **Beginner (Sections 1-2)**: Environment setup and basic integration
# - **Intermediate (Sections 3-4)**: Hybrid architecture and AI integration
# - **Advanced (Sections 5-6)**: Production workflows and complete solutions
#
# ### 🎯 Competency Indicators
# - **100% Section 1**: Ready for basic AgentCore development
# - **100% Sections 1-3**: Capable of hybrid integration projects
# - **100% Sections 1-5**: Ready for production CAPTCHA handling systems
# - **100% All Sections**: Expert-level enterprise integration skills
#
# ## 🤝 Getting Additional Help
#
# ### 📚 Documentation Resources
# - **Main Tutorial**: `agentcore-enterprise-captcha-handling.ipynb`
# - **Integration Guide**: `HYBRID_INTEGRATION_SUMMARY.md`
# - **Performance Guide**: `performance_optimization_guide.md`
# - **Comparison Guide**: `AGENTCORE_VS_BROWSER_USE_COMPARISON.md`
#
# ### 🔍 Debugging Strategies
# 1. **Isolate Issues**: Run individual validation sections to pinpoint problems
# 2. **Check Logs**: Review error messages and suggestions carefully
# 3. **Verify Environment**: Ensure all prerequisites are properly configured
# 4. **Test Incrementally**: Validate after each tutorial section completion
#
# ### 🌟 Success Strategies
# - **Follow Sequentially**: Complete tutorial sections in order
# - **Validate Frequently**: Run validation after each major step
# - **Read Suggestions**: Pay attention to specific recommendations
# - **Practice Patience**: Complex integrations take time to master
#
# ---
#
# ## 🎉 Validation Complete!
#
# Thank you for using the CAPTCHA Handling Tutorial validation framework. This tool helps ensure you're building robust, enterprise-ready CAPTCHA handling solutions with confidence.
#
# **Keep building amazing things! 🚀**
