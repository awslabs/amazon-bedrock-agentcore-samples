# %% [markdown]
# # Event metadata and filtering
#
# > **Status:** placeholder — content to be written.
#
# ## Scope
#
# - Attaching structured metadata to an event on `CreateEvent`.
# - Filtering `ListEvents` by metadata tags.
# - Common tagging patterns: tool calls, source channel, intent labels.
#
# Surface: **boto3**.
