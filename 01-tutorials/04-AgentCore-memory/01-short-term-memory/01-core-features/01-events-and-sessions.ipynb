# %% [markdown]
# # Events and sessions
#
# > **Status:** placeholder — content to be written.
#
# ## Scope
#
# - `CreateEvent` — writing a conversation turn to short-term memory.
# - `ListEvents` — paginating through events for an `actorId` + `sessionId`.
# - `GetEvent` — fetching a single event by ID.
# - `DeleteEvent` — removing an event.
# - When to split sessions vs extend an existing one.
#
# Surface: **boto3** (`bedrock-agentcore` data-plane client).
