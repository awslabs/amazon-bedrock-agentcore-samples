# %% [markdown]
# # Actor and session isolation
#
# > **Status:** placeholder — content to be written.
#
# ## Scope
#
# - Modelling users / agents / system principals as actors.
# - Grouping related turns into sessions; when to start a new one.
# - Reading only a single actor's or session's events.
# - Implications for tenant isolation — leads into the IAM patterns in [`../../04-security-patterns/`](../../04-security-patterns/).
#
# Surface: **boto3**.
