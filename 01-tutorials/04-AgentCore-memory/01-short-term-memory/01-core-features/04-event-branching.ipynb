# %% [markdown]
# # Event branching primitive
#
# > **Status:** placeholder — content to be written.
#
# ## Scope
#
# - Creating a branch from an existing event via `branchId`.
# - Listing events on a specific branch.
# - Merging / discarding branches.
# - Contrast with the higher-level agent-branching examples in [`../02-single-agent/with-strands-agent/travel-planning-branching/`](../02-single-agent/with-strands-agent/travel-planning-branching/) and [`../03-multi-agent/with-strands-agent/multi-agent-parallel-branches/`](../03-multi-agent/with-strands-agent/multi-agent-parallel-branches/).
#
# Surface: **boto3**.
