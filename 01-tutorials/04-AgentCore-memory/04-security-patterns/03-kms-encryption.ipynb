# %% [markdown]
# # KMS encryption on a memory resource
#
# > **Status:** placeholder — content to be written.
#
# ## Scope
#
# - Creating or updating a memory resource with a customer-managed KMS key (`kmsKeyArn`).
# - Minimum key policy statements the memory service needs.
# - How encryption applies to events, records, and streamed payloads.
# - Key rotation considerations.
#
# Surface: **boto3** + AWS KMS console / CLI.
