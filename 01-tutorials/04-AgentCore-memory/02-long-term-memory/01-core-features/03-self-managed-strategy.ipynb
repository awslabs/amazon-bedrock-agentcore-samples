# %% [markdown]
# # Self-managed strategy
#
# > **Status:** placeholder — content to be written.
#
# ## Scope
#
# - Defining a self-managed strategy with your own extraction and consolidation Lambdas.
# - IAM wiring between AgentCore Memory and your Lambda functions.
# - Designing record schemas — what to store, how to key it.
# - See also: [`../../02-single-agent/with-strands-agent/02-custom-hook/culinary-assistant-self-managed-strategy/`](../../02-single-agent/with-strands-agent/02-custom-hook/culinary-assistant-self-managed-strategy/) for a Strands agent using this pattern end to end.
#
# Surface: **boto3** (control plane) + Lambda.
