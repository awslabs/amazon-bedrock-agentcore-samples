# %% [markdown]
# # Redrive failed ingestions
#
# > **Status:** placeholder — content to be written.
#
# ## Scope
#
# - Identifying events whose extraction failed.
# - `Redrive` API — retrying a specific event or batch.
# - Diagnosing recurring failures via CloudWatch.
#
# Surface: **boto3**.
