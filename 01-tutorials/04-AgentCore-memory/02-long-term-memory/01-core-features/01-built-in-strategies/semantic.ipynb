# %% [markdown]
# # Built-in strategy — Semantic
#
# > **Status:** placeholder — content to be written.
#
# ## Scope
#
# - What the semantic strategy extracts: standalone facts from conversation.
# - Creating a memory resource with a semantic strategy (`semanticMemoryStrategy`).
# - Writing events, waiting for extraction (~1 minute).
# - Retrieving with `RetrieveMemoryRecords` via natural-language queries.
# - When to prefer Semantic over Summary or User Preference.
#
# Surface: **boto3**.
