# %% [markdown]
# # Built-in strategy — User Preference
#
# > **Status:** placeholder — content to be written.
#
# ## Scope
#
# - What the user-preference strategy captures: stable per-user settings.
# - Configuring `userPreferenceMemoryStrategy` with an `{actorId}`-scoped namespace.
# - Reading and updating preferences across sessions.
# - Compared with Semantic: preferences are about the actor, facts are about the world.
#
# Surface: **boto3**.
