# %% [markdown]
# # Built-in strategy — Episodic
#
# > **Status:** placeholder — content to be written.
#
# ## Scope
#
# - What the episodic strategy captures: meaningful sequences of interactions (episodes).
# - Automatic episode detection, consolidation, and reflection.
# - Retrieving episodes by similarity and time.
# - When to prefer Episodic over Summary (sequences vs. standing state).
#
# Surface: **boto3**.
