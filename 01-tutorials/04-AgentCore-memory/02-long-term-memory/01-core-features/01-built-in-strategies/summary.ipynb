# %% [markdown]
# # Built-in strategy — Summary
#
# > **Status:** placeholder — content to be written.
#
# ## Scope
#
# - What the summary strategy produces: rolling conversation summaries.
# - Configuring `summaryMemoryStrategy` with a `{sessionId}`-scoped namespace.
# - Reading the current summary for a session.
# - When to use Summary alongside Semantic or Episodic.
#
# Surface: **boto3**.
