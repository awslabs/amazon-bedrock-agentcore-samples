# %% [markdown]
# # Structured metadata on records
#
# > **Status:** placeholder — content to be written.
#
# ## Scope
#
# - Attaching typed metadata to a memory record.
# - Filtering retrieval by metadata.
# - Common schemas: source, confidence, tenancy tags.
#
# Surface: **boto3**.
