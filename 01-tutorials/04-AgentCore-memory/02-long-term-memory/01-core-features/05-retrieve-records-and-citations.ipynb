# %% [markdown]
# # Retrieve records and citations
#
# > **Status:** placeholder — content to be written.
#
# ## Scope
#
# - `RetrieveMemoryRecords` with semantic queries.
# - `ListMemoryRecords` and `GetMemoryRecord` for deterministic access.
# - Citation payloads — how to surface the source events behind a record.
#
# Surface: **boto3**.
