# %% [markdown]
# # Strategies with overrides
#
# > **Status:** placeholder — content to be written.
#
# ## Scope
#
# - Using `semanticOverride` / `summaryOverride` / `userPreferenceOverride` to customize extraction and consolidation prompts on a built-in strategy.
# - Choosing the model ID used for extraction vs. consolidation.
# - When overrides are enough vs. when to jump to self-managed (notebook 03).
#
# Surface: **boto3**.
