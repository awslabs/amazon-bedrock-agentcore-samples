# %% [markdown]
# # Amazon Bedrock AgentCore Observability with LlamaIndex hosted outside of AgentCore Runtime
#
# This notebook demonstrates how to use setup observability for a [Llama Index Agent](https://docs.llamaindex.ai/en/stable/use_cases/agents/)  agent hosted outside of Amazon Bedrock AgentCore Runtime. Once you have completed the setup, you will be able to view the internal decision making process of the LlamaIndex agent in GenAI Observability dashboard in Amazon CloudWatch.
#
# ## What you'll learn
# - How to set up LlamaIndex agent with Amazon OpenTelemetry Python Instrumentation
# - How to visualize and analyze agent traces in Amazon CloudWatch GenAI Observability

# %% [markdown]
# ## Prerequisites
# - Enable transaction search on Amazon CloudWatch. First-time users must enable CloudWatch Transaction Search to view Bedrock AgentCore spans and traces. To enable transaction search, please refer to the our [documentation](https://docs.aws.amazon.com/AmazonCloudWatch/latest/monitoring/Enable-TransactionSearch.html).
# - Log group and Log stream configured on Amazon Cloudwatch to be added to the environment variables.
# - AWS account with Amazon Bedrock Model access to Claude Haiku with Model ID: anthropic.claude-3-haiku-20240307-v1:0
# - AWS credentials configured using `aws configure`
# - .env file updated with environment variables variables. An example is provided in `.env.example`

# %% [markdown]
# ## 1. Setup and Installation
#
# First, let's install the required dependencies. Please check that `aws-opentelemetry-distro` in your requirements.txt file.

# %%
# !pip install --force-reinstall -U -r requirements.txt --quiet
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# retinaface 1.1.1 requires streamlit-webrtc==0.42.0, which is not installed.
# litellm 1.68.0 requires openai<1.76.0,>=1.68.2, but you have openai 1.100.2 which is incompatible.
# mlflow-skinny 2.20.2 requires packaging<25, but you have packaging 25.0 which is incompatible.
# retinaface 1.1.1 requires opencv-python-headless==4.6.0.66, but you have opencv-python-headless 4.10.0.84 which is incompatible.
# retinaface 1.1.1 requires streamlit==1.10.0, but you have streamlit 1.31.0 which is incompatible.
# retinaface 1.1.1 requires tensorflow==2.5.0, but you have tensorflow 1.12.0 which is incompatible.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.3.2 which is incompatible.
# instructor 1.8.3 requires jiter<0.9,>=0.6.1, but you have jiter 0.10.0 which is incompatible.
# instructor 1.8.3 requires rich<14.0.0,>=13.7.0, but you have rich 14.1.0 which is incompatible.
# pyarrow 15.0.0 requires numpy<2,>=1.16.6, but you have numpy 2.3.2 which is incompatible.
# langchain-core 0.3.65 requires packaging<25,>=23.2, but you have packaging 25.0 which is incompatible.
# datasets 3.6.0 requires dill<0.3.9,>=0.3.0, but you have dill 0.4.0 which is incompatible.
# datasets 3.6.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.7.0 which is incompatible.
# fastapi 0.115.9 requires starlette<0.46.0,>=0.40.0, but you have starlette 0.47.2 which is incompatible.
# aws-cdk-cx-api 1.204.0 requires aws-cdk.cloud-assembly-schema==1.204.0, but you have aws-cdk-cloud-assembly-schema 41.2.0 which is incompatible.
# matplotlib 3.8.2 requires numpy<2,>=1.21, but you have numpy 2.3.2 which is incompatible.
# streamlit 1.31.0 requires importlib-metadata<8,>=1.4, but you have importlib-metadata 8.6.1 which is incompatible.
# streamlit 1.31.0 requires numpy<2,>=1.19.3, but you have numpy 2.3.2 which is incompatible.
# streamlit 1.31.0 requires packaging<24,>=16.8, but you have packaging 25.0 which is incompatible.
# streamlit 1.31.0 requires pillow<11,>=7.1.0, but you have pillow 11.3.0 which is incompatible.
# streamlit 1.31.0 requires protobuf<5,>=3.20, but you have protobuf 5.29.5 which is incompatible.
# streamlit 1.31.0 requires rich<14,>=10.14.0, but you have rich 14.1.0 which is incompatible.
# streamlit 1.31.0 requires tenacity<9,>=8.1.0, but you have tenacity 9.1.2 which is incompatible.
#
# [notice] A new release of pip is available: 23.3.2 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# #### Deploying pre-requisites
#
# Before starting let's create a log group and a log stream for AgentCore observability

# %%
import boto3
cloudwatch_client = boto3.client("logs")
response = cloudwatch_client.create_log_group(
    logGroupName='agents/llama-index-agent-logs'
)
response
# Out:
# ---------------------------------------------------------------------------
# ResourceAlreadyExistsException            Traceback (most recent call last)
# Cell In[1], line 3
#       1 import boto3
#       2 cloudwatch_client = boto3.client("logs")
# ----> 3 response = cloudwatch_client.create_log_group(
#       4     logGroupName='agents/llama-index-agent-logs'
#       5 )
#       6 response
#
# File ~/llamaindex-agentcore-observability/nb_venv/lib/python3.12/site-packages/botocore/client.py:601, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     597     raise TypeError(
#     598         f"{py_operation_name}() only accepts keyword arguments."
#     599     )
#     600 # The "self" in this scope is referring to the BaseClient.
# --> 601 return self._make_api_call(operation_name, kwargs)
#
# File ~/llamaindex-agentcore-observability/nb_venv/lib/python3.12/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~/llamaindex-agentcore-observability/nb_venv/lib/python3.12/site-packages/botocore/client.py:1074, in BaseClient._make_api_call(self, operation_name, api_params)
#    1070     error_code = request_context.get(
#    1071         'error_code_override'
#    1072     ) or error_info.get("Code")
#    1073     error_class = self.exceptions.from_code(error_code)
# -> 1074     raise error_class(parsed_response, operation_name)
#    1075 else:
#    1076     return parsed_response
#
# ResourceAlreadyExistsException: An error occurred (ResourceAlreadyExistsException) when calling the CreateLogGroup operation: The specified log group already exists

# %%
response = cloudwatch_client.create_log_stream(
    logGroupName='agents/llama-index-agent-logs',
    logStreamName='default'
)
response
# Out:
# ---------------------------------------------------------------------------
# ResourceAlreadyExistsException            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 response = cloudwatch_client.create_log_stream(
#       2     logGroupName='agents/llama-index-agent-logs',
#       3     logStreamName='default'
#       4 )
#       5 response
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/botocore/client.py:601, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     597     raise TypeError(
#     598         f"{py_operation_name}() only accepts keyword arguments."
#     599     )
#     600 # The "self" in this scope is referring to the BaseClient.
# --> 601 return self._make_api_call(operation_name, kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/botocore/client.py:1074, in BaseClient._make_api_call(self, operation_name, api_params)
#    1070     error_code = request_context.get(
#    1071         'error_code_override'
#    1072     ) or error_info.get("Code")
#    1073     error_class = self.exceptions.from_code(error_code)
# -> 1074     raise error_class(parsed_response, operation_name)
#    1075 else:
#    1076     return parsed_response
#
# ResourceAlreadyExistsException: An error occurred (ResourceAlreadyExistsException) when calling the CreateLogStream operation: The specified log stream already exists

# %% [markdown]
# #### Enabling transactional search
#
# To run this example you first need to enable transactional search. You can do so in the AWS console following this [link](https://console.aws.amazon.com/cloudwatch/home#xray:settings/transaction-search).
#
# Once in this page, click on edit and set the option to ingest spans as structured logs in the OpenTelemetry format
# ![image.png](./images/transactional_search.png)
# ![image.png](./images/transactional_search2.png)

# %% [markdown]
# ## 2. Environment Configuration
# To enable observability for your LlamaIndex agent and send telemetry data to Amazon CloudWatch, you'll need to configure the following environment variables. We use a `.env` file to manage these settings securely, keeping sensitive AWS credentials separate from your code while making it easy to switch between different environments.
#
# **Ensure your AWS credentials are configured**
#
# We will create a `.env` file for configuring the environment variables. Use `env.example` as a template.
#
# Required Environment Variables:
#
# | Variable | Value | Purpose |
# |----------|-------|---------|
# | `OTEL_PYTHON_DISTRO` | `aws_distro` | Use AWS Distro for OpenTelemetry (ADOT) |
# | `OTEL_PYTHON_CONFIGURATOR` | `aws_configurator` | Set AWS configurator for ADOT SDK |
# | `OTEL_EXPORTER_OTLP_PROTOCOL` | `http/protobuf` | Configure export protocol |
# | `OTEL_EXPORTER_OTLP_LOGS_HEADERS` | `x-aws-log-group=<YOUR-LOG-GROUP>,x-aws-log-stream=<YOUR-LOG-STREAM>,x-aws-metric-namespace=<YOUR-NAMESPACE>` | Direct logs to CloudWatch groups |
# | `OTEL_RESOURCE_ATTRIBUTES` | `service.name=<YOUR-AGENT-NAME>` | Identify your agent in observability data |
# | `AGENT_OBSERVABILITY_ENABLED` | `true` | Activate ADOT pipeline |
# | `AWS_REGION` | `<YOUR-REGION>` | AWS Region |

# %%
# %%writefile .env
# # AWS OpenTelemetry Distribution
# OTEL_PYTHON_DISTRO=aws_distro
# OTEL_PYTHON_CONFIGURATOR=aws_configurator
#
# # Export Protocol
# OTEL_EXPORTER_OTLP_PROTOCOL=http/protobuf
# OTEL_TRACES_EXPORTER=otlp
#
# # CloudWatch Integration (uncomment and configure as needed)
# OTEL_EXPORTER_OTLP_LOGS_HEADERS=x-aws-log-group=agents/llama-index-agent-logs,x-aws-log-stream=default,x-aws-metric-namespace=bedrock-agentcore
#
# # Service Identification
# OTEL_RESOURCE_ATTRIBUTES=service.name=agentic-llamaindex-agentcore
# # Enable Agent Observability
# AGENT_OBSERVABILITY_ENABLED=true
# Out:
# Overwriting .env

# %% [markdown]
# ## 3. Load Environment Variables
#
# Let's load the environment variables from the `.env` file:

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Display the OTEL-related environment variables
otel_vars = [
    "OTEL_PYTHON_DISTRO",
    "OTEL_PYTHON_CONFIGURATOR",
    "OTEL_EXPORTER_OTLP_PROTOCOL",
    "OTEL_EXPORTER_OTLP_LOGS_HEADERS",
    "OTEL_RESOURCE_ATTRIBUTES",
    "AGENT_OBSERVABILITY_ENABLED",
    "OTEL_TRACES_EXPORTER"
]

print("OpenTelemetry Configuration:")
for var in otel_vars:
    value = os.getenv(var)
    if value:
        print(f"{var}={value}")
# Out:
# OpenTelemetry Configuration:
# OTEL_PYTHON_DISTRO=aws_distro
# OTEL_PYTHON_CONFIGURATOR=aws_configurator
# OTEL_EXPORTER_OTLP_PROTOCOL=http/protobuf
# OTEL_EXPORTER_OTLP_LOGS_HEADERS=x-aws-log-group=agents/llama-index-agent-logs,x-aws-log-stream=default,x-aws-metric-namespace=bedrock-agentcore
# OTEL_RESOURCE_ATTRIBUTES=service.name=agentic-llamaindex-agentcore
# AGENT_OBSERVABILITY_ENABLED=true
# OTEL_TRACES_EXPORTER=otlp

# %% [markdown]
# ## 4. Create a LlamaIndex Agent in a python file
#
# LlamaIndex arithmetic agent implementation is provided in `llama_index_agent.py`. It is a simple arithmetic agent set up with a Claude 3 Haiku model from Amazon Bedrock. The AWS OpenTelemetry distro will automatically handle tracer provider setup when using `opentelemetry-instrument` command.
#
# The agent is a simple arithmetic agent that:
#
# - Creates a FunctionAgent using AWS Bedrock's Claude Haiku model
# - Defines basic arithmetic tools for addition and multiplication
# - Gives the agent a task to calculate a simple mathematical expression: (121 + 2) * 5
# - Runs the agent and returns the calculated result
#
# The Agent is Configured with the following:
#
# - Two arithmetic function tools: add and multiply
# - Amazon Bedrock's Claude Haiku model as its Large Language Model
# - OpenTelemetry instrumentation for tracing and observability
#
# The agent is executed asynchronously using the agent's run method, which processes the math query and returns the result.

# %%
# %%writefile llama_index_agent.py
###########################
#### Agent Code below: ####
###########################
import os
import asyncio
import logging
from llama_index.observability.otel import LlamaIndexOpenTelemetry
from llama_index.llms.bedrock_converse import BedrockConverse
from llama_index.core.agent.workflow import FunctionAgent

# Initialize OpenTelemetry instrumentation for LlamaIndex
instrumentor = LlamaIndexOpenTelemetry(debug=True)

# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Configure LlamaIndex logging
logging.getLogger("llamaindex").setLevel(logging.INFO)

def multiply(a: int, b: int) -> int:
    """Multiple two integers and returns the result integer"""
    return a * b


def add(a: int, b: int) -> int:
    """Add two integers and returns the result integer"""
    return a + b


def get_bedrock_model():
    model_id = os.getenv("BEDROCK_MODEL_ID", "anthropic.claude-3-haiku-20240307-v1:0")
    region = os.getenv("AWS_DEFAULT_REGION", "us-west-2")
    
    try:
        bedrock_model = BedrockConverse(
            model=model_id,
            aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
            aws_secret_access_key=os.getenv("AWS_SECRET_ACCESS_KEY"),
            region_name=region,
        )
        logger.info(f"Successfully initialized Bedrock model: {model_id} in region: {region}")
        return bedrock_model
    except Exception as e:
        logger.error(f"Failed to initialize Bedrock model: {str(e)}")
        logger.error("Please ensure you have proper AWS credentials configured and access to the Bedrock model")
        raise

# Initialize the model
bedrock_model = get_bedrock_model()

# Create the travel agent
agent = FunctionAgent(
    tools=[add, multiply],
    llm=bedrock_model,
)

# Start listening
instrumentor.start_registering()

# Execute the arithmetic task
query = """What is (121 + 2) * 5?"""

async def main():
    result = await agent.run(query)
    print("Result:", str(result))

asyncio.run(main())
# Out:
# Writing llama_index_agent.py

# %% [markdown]
# ## 5. AWS OpenTelemetry Python Distro
#
# Now that your environment is configured, let's understand how the observability happens. The [AWS OpenTelemetry Python Distro](https://pypi.org/project/aws-opentelemetry-distro/) automatically instruments your Strands agent to capture telemetry data without requiring code changes.
#
# This distribution provides:
# - **Auto-instrumentation** for your Strands Agent hosted outside of AgentCore Runtime (i.e. EC2, Lambda etc..)
# - **AWS-optimized configuration** for seamless CloudWatch integration
#
# ### Running Your Instrumented Agent
#
# To capture traces from your LlamaIndex agent, use the `opentelemetry-instrument` command instead of running Python directly. This automatically applies instrumentation using the environment variables from your `.env` file:
#
# ```bash
# opentelemetry-instrument python llama_index_agent.py
# ```
#
# This command will:
#
# - Load your OTEL configuration from the .env file
# - Automatically instrument LlamaIndex, Amazon Bedrock calls, agent tool and databases, and other requests made by agent
# - Send traces to CloudWatch
# - Enable you to visualize the agent's decision-making process in the GenAI Observability dashboard

# %%
# !opentelemetry-instrument python llama_index_agent.py
# Out:
# INFO:__main__:Successfully initialized Bedrock model: anthropic.claude-3-haiku-20240307-v1:0 in region: us-west-2
# WARNING:opentelemetry.trace:Overriding of current TracerProvider is not allowed
# Emitting span FunctionAgent.run-e896c991-cb4c-4b19-8ce0-f87844d594ac at time: 2025-08-21 11:25:25.177556
# Emitting span FunctionAgent.init_run-4b86aa41-782f-418c-b560-fd86c4b33c85 at time: 2025-08-21 11:25:25.179928
# Preparing to end span FunctionAgent.init_run-4b86aa41-782f-418c-b560-fd86c4b33c85 at time: 2025-08-21 11:25:25.470108
# Emitting span FunctionAgent.setup_agent-1993ffa7-c99c-4a33-87a5-c7a8b02ec1bf at time: 2025-08-21 11:25:25.471103
# Preparing to end span FunctionAgent.setup_agent-1993ffa7-c99c-4a33-87a5-c7a8b02ec1bf at time: 2025-08-21 11:25:25.471571
# Emitting span FunctionAgent.run_agent_step-b5981247-ad6b-4b79-8276-e2dc0df7c4b0 at time: 2025-08-21 11:25:25.472321
# INFO:botocore.credentials:Found credentials in environment variables.
# INFO:botocore.credentials:Found credentials in environment variables.
# Emitting span BedrockConverse._prepare_chat_with_tools-a74cc98c-7f8c-4b08-afeb-58dc393ce77c at time: 2025-08-21 11:25:26.425478
# Preparing to end span BedrockConverse._prepare_chat_with_tools-a74cc98c-7f8c-4b08-afeb-58dc393ce77c at time: 2025-08-21 11:25:26.430358
# Emitting span BedrockConverse.astream_chat-80942edf-5c04-4267-9ad3-1e8d13a886d0 at time: 2025-08-21 11:25:26.431744
# Registering a LLMChatStartEvent event at time: 2025-08-21 11:25:26.432029
# Preparing to end span BedrockConverse.astream_chat-80942edf-5c04-4267-9ad3-1e8d13a886d0 at time: 2025-08-21 11:25:26.432575
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:25:27.239283
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:25:27.239737
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:25:27.240099
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:25:27.240439
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:25:27.307916
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:25:27.498722
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:25:27.499265
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:25:27.677461
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:25:27.678572
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:25:28.011771
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:25:28.012358
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:25:28.015779
# ERROR:opentelemetry.context:Failed to detach context
# Traceback (most recent call last):
#   File "/Users/sslavich/llamaindex-agentcore-observability/nb_venv/lib/python3.12/site-packages/opentelemetry/context/__init__.py", line 155, in detach
#     _RUNTIME_CONTEXT.detach(token)
#   File "/Users/sslavich/llamaindex-agentcore-observability/nb_venv/lib/python3.12/site-packages/opentelemetry/context/contextvars_context.py", line 53, in detach
#     self._current_context.reset(token)
# ValueError: <Token var=<ContextVar name='current_context' default={} at 0
# Preparing to end span FunctionTool.acall-c905de86-51a8-4e9c-ade0-a451af6f3b55 at time: 2025-08-21 11:25:29.362557
# Preparing to end span FunctionAgent.call_tool-23de339e-e223-4b93-ba66-1ff25fdfa069 at time: 2025-08-21 11:25:29.362994
# Emitting span FunctionAgent.aggregate_tool_results-4c69ebbb-21d9-4232-957f-9c25de0cb7c3 at time: 2025-08-21 11:25:29.363817
# Preparing to end span FunctionAgent.aggregate_tool_results-4c69ebbb-21d9-4232-957f-9c25de0cb7c3 at time: 2025-08-21 11:25:29.364937
# Emitting span FunctionAgent.setup_agent-bc79a0eb-691b-4eec-b3ef-6a849ea8e342 at time: 2025-08-21 11:25:29.366038
# Preparing to end span FunctionAgent.setup_agent-bc79a0eb-691b-4eec-b3ef-6a849ea8e342 at time: 2025-08-21 11:25:29.366534
# Emitting span FunctionAgent.run_agent_step-5d7ef847-7e58-4d71-b8de-9baae101fa82 at time: 2025-08-21 11:25:29.367439
# Emitting span BedrockConverse._prepare_chat_with_tools-5b78975a-cc15-4d34-a3dc-75ad0c174a03 at time: 2025-08-21 11:25:29.368898
# Preparing to end span BedrockConverse._prepare_chat_with_tools-5b78975a-cc15-4d34-a3dc-75ad0c174a03 at time: 2025-08-21 11:25:29.371207
# Emitting span BedrockConverse.astream_chat-eb38eb19-0a87-40d7-ac41-a6947102a8cf at time: 2025-08-21 11:25:29.372908
# Registering a LLMChatStartEvent event at time: 2025-08-21 11:25:29.373418
# Preparing to end span BedrockConverse.astream_chat-eb38eb19-0a87-40d7-ac41-a6947102a8cf at time: 2025-08-21 11:25:29.373921
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:25:30.350194
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:25:30.350826
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:25:30.351360
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:25:30.351896
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:25:30.352421
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:25:30.353190
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:25:30.353917
# Registering a LLMChatEndEvent event at time: 2025-08-21 11:25:30.357789
# WARNING:opentelemetry.sdk.trace:Setting attribute on ended span.
# Preparing to end span FunctionAgent.run_agent_step-5d7ef847-7e58-4d71-b8de-9baae101fa82 at time: 2025-08-21 11:25:30.358549
# Emitting span FunctionAgent.parse_agent_output-d2f80e40-e954-486e-9e08-2d73c03070ca at time: 2025-08-21 11:25:30.359516
# Preparing to end span FunctionAgent.parse_agent_output-d2f80e40-e954-486e-9e08-2d73c03070ca at time: 2025-08-21 11:25:30.360939
# Emitting span FunctionAgent._done-cdf6c26d-68ba-482b-b6da-7b749082fdbc at time: 2025-08-21 11:25:30.361852
# Registering a SpanDropEvent event at time: 2025-08-21 11:25:30.362146
# Preparing to exit span FunctionAgent._done-cdf6c26d-68ba-482b-b6da-7b749082fdbc with an error at time: 2025-08-21 11:25:30.362341
# WARNING:opentelemetry.sdk.trace:Setting attribute on ended span.
# Preparing to end span FunctionAgent.run-e896c991-cb4c-4b19-8ce0-f87844d594ac at time: 2025-08-21 11:25:30.363824
# Result: Therefore, the result of (121 + 2) * 5 is 615.

# %% [markdown]
# ## 6. Adding Session Tracking
#
# To correlate traces across multiple agent runs, you can associate a session ID with your telemetry data using OpenTelemetry baggage:
#
# ```python
# from opentelemetry import baggage, context
# ctx = baggage.set_baggage("session.id", session_id)
# ```
#
# Run the session-enabled version:
# ```bash
# opentelemetry-instrument python llama_indedx_agent_with_session.py --session-id "user-session-123"
# ```
#
# ## 7. Custom Metadata for Analysis
# Add custom attributes to enable filtering, offline evaluations, and performance analysis. You would need to modify your agent code to accept additional parameters:
# ```python
# ctx = baggage.set_baggage("user.type", "premium")
# ctx = baggage.set_baggage("experiment.id", "llama-agent")
# ctx = baggage.set_baggage("conversation.topic", "arithmetic")
# ```
#
# Example commands with custom metadata:
#
# ```bash
# # A/B testing different experiments
# opentelemetry-instrument python agent.py --session-id "session-123" --experiment-id "model-a"
# opentelemetry-instrument python agent.py --session-id "session-124" --experiment-id "model-b"
#
# # Tracking different user types
# opentelemetry-instrument python agent.py --session-id "session-125" --user-type "premium"
# opentelemetry-instrument python agent.py --session-id "session-126" --user-type "free"
#
# # Offline evaluation runs
# opentelemetry-instrument python agent.py --session-id "eval-001" --dataset "golden-set-v1"
# ```
# These attributes appear in CloudWatch traces for advanced filtering and analysis.

# %%
# %%writefile llama_index_agent_with_session.py
import os
import logging
import argparse
import asyncio
from opentelemetry import baggage, context
from llama_index.observability.otel import LlamaIndexOpenTelemetry
from llama_index.llms.bedrock_converse import BedrockConverse
from llama_index.core.agent.workflow import FunctionAgent

def parse_arguments():
    parser = argparse.ArgumentParser(description='LlamaIndex Arithmetic Agent with Session Tracking')
    parser.add_argument('--session-id', 
                       type=str, 
                       required=True,
                       help='Session ID to associate with this agent run')
    return parser.parse_args()

def set_session_context(session_id):
    """Set the session ID in OpenTelemetry baggage for trace correlation"""
    ctx = baggage.set_baggage("session.id", session_id)
    token = context.attach(ctx)
    logging.info(f"Session ID '{session_id}' attached to telemetry context")
    return token

###########################
#### Agent Code below: ####
###########################

# Initialize OpenTelemetry instrumentation for LlamaIndex
instrumentor = LlamaIndexOpenTelemetry(debug=True)

# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Configure LlamaIndex logging
logging.getLogger("llamaindex").setLevel(logging.INFO)

def multiply(a: int, b: int) -> int:
    """Multiple two integers and returns the result integer"""
    return a * b

def add(a: int, b: int) -> int:
    """Add two integers and returns the result integer"""
    return a + b

def get_bedrock_model():
    model_id = os.getenv("BEDROCK_MODEL_ID", "anthropic.claude-3-haiku-20240307-v1:0")
    region = os.getenv("AWS_DEFAULT_REGION", "us-west-2")
    
    try:
        bedrock_model = BedrockConverse(
            model=model_id,
            aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
            aws_secret_access_key=os.getenv("AWS_SECRET_ACCESS_KEY"),
            region_name=region,
        )
        logger.info(f"Successfully initialized Bedrock model: {model_id} in region: {region}")
        return bedrock_model
    except Exception as e:
        logger.error(f"Failed to initialize Bedrock model: {str(e)}")
        logger.error("Please ensure you have proper AWS credentials configured and access to the Bedrock model")
        raise

async def run_agent(query):
    # Initialize the model
    bedrock_model = get_bedrock_model()

    # Create the arithmetic agent
    agent = FunctionAgent(
        tools=[add, multiply],
        llm=bedrock_model,
    )

    # Start listening
    instrumentor.start_registering()

    # Execute the arithmetic task
    result = await agent.run(query)
    print("Result:", str(result))
    return result

def main():
    # Parse command line arguments
    args = parse_arguments()
    
    # Set session context for telemetry
    context_token = set_session_context(args.session_id)
    
    try:
        # Execute the arithmetic task
        query = """What is (121 + 2) * 5?"""
        
        # Run the async function in the event loop
        result = asyncio.run(run_agent(query))
        
    finally:
        # Detach context when done
        try:
            context.detach(context_token)
            logger.info(f"Session context for '{args.session_id}' detached")
        except ValueError as e:
            # Handle the context detachment error that might occur
            logger.error(f"Error detaching context: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# Writing llama_index_agent_with_session.py

# %%
# !opentelemetry-instrument python llama_index_agent_with_session.py --session-id "session-1234"
# Out:
# INFO:root:Session ID 'session-1234' attached to telemetry context
# INFO:__main__:Successfully initialized Bedrock model: anthropic.claude-3-haiku-20240307-v1:0 in region: us-west-2
# WARNING:opentelemetry.trace:Overriding of current TracerProvider is not allowed
# Emitting span FunctionAgent.run-55643190-156a-43f0-a33c-b7fe18adf3e7 at time: 2025-08-21 11:47:30.050731
# Emitting span FunctionAgent.init_run-34365855-4ded-496e-9d27-98e479fd3cd5 at time: 2025-08-21 11:47:30.053006
# Preparing to end span FunctionAgent.init_run-34365855-4ded-496e-9d27-98e479fd3cd5 at time: 2025-08-21 11:47:30.282274
# Emitting span FunctionAgent.setup_agent-04bc04b0-a6bc-4cdf-ae42-fee877dfa173 at time: 2025-08-21 11:47:30.283219
# Preparing to end span FunctionAgent.setup_agent-04bc04b0-a6bc-4cdf-ae42-fee877dfa173 at time: 2025-08-21 11:47:30.283642
# Emitting span FunctionAgent.run_agent_step-511d50f5-01e6-49f2-899c-e7570948f5eb at time: 2025-08-21 11:47:30.284407
# INFO:botocore.credentials:Found credentials in environment variables.
# INFO:botocore.credentials:Found credentials in environment variables.
# Emitting span BedrockConverse._prepare_chat_with_tools-aa7128e0-566e-49a0-91c8-b1357a769805 at time: 2025-08-21 11:47:31.123549
# Preparing to end span BedrockConverse._prepare_chat_with_tools-aa7128e0-566e-49a0-91c8-b1357a769805 at time: 2025-08-21 11:47:31.128327
# Emitting span BedrockConverse.astream_chat-a568b058-8b09-417c-a64c-da6ec62f0e30 at time: 2025-08-21 11:47:31.129907
# Registering a LLMChatStartEvent event at time: 2025-08-21 11:47:31.130349
# Preparing to end span BedrockConverse.astream_chat-a568b058-8b09-417c-a64c-da6ec62f0e30 at time: 2025-08-21 11:47:31.131681
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:47:31.783827
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:47:31.883337
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:47:31.922168
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:47:32.072231
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:47:32.429721
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:47:32.725180
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:47:32.725999
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:47:33.078197
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:47:33.079038
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:47:33.079547
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:47:33.080171
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:47:33.089576
# ERROR:opentelemetry.context:Failed to detach context
# Traceback (most recent call last):
#   File "/Users/sslavich/llamaindex-agentcore-observability/nb_venv/lib/python3.12/site-packages/opentelemetry/context/__init__.py", line 155, in detach
#     _RUNTIME_CONTEXT.detach(token)
#   File "/Users/sslavich/llamaindex-agentcore-observability/nb_venv/lib/python3.12/site-packages/opentelemetry/context/contextvars_context.py", line 53, in detach
#     self._current_context.reset(token)
# ValueError: <Token var=<ContextVar name='current_context' default={} at 0x1101cabb0> at 0x11d5cbc80> was created in a different Context
# Registering a LLMChatEndEvent event at time: 2025-08-21 11:47:33.102081
# WARNING:opentelemetry.sdk.trace:Setting attribute on ended span.
# Preparing to end span FunctionAgent.run_agent_step-511d50f5-01e6-49f2-899c-e7570948f5eb at time: 2025-08-21 11:47:33.102915
# Emitting span FunctionAgent.parse_agent_output-bdf715f0-7907-4363-9405-576e2344782c at time: 2025-08-21 11:47:33.103866
# Preparing to end span FunctionAgent.parse_agent_output-bdf715f0-7907-4363-9405-576e2344782c at time: 2025-08-21 11:47:33.104134
# Emitting span FunctionAgent.call_tool-b172a475-40c6-4d1f-9411-37da877c5a1c at time: 2025-08-21 11:47:33.104823
# Emitting span FunctionTool.acall-ea1171e3-c8dd-4598-96e5-8690737ae105 at time: 2025-08-21 11:47:33.105968
# Preparing to end span FunctionTool.acall-ea1171e3-c8dd-4598-96e5-8690737ae105 at time: 2025-08-21 11:47:33.106622
# Preparing to end span FunctionAgent.call_tool-b172a475-40c6-4d1f-9411-37da877c5a1c at time: 2025-08-21 11:47:33.107054
# Emitting span FunctionAgent.aggregate_tool_results-1890605f-333c-40f4-9d4f-41821171adc1 at time: 2025-08-21 11:47:33.107801
# Preparing to end span FunctionAgent.aggregate_tool_results-1890605f-333c-40f4-9d4f-41821171adc1 at time: 2025-08-21 11:47:33.108624
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:47:34.868811
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:47:34.981297
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:47:34.983036
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:47:35.002927
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:47:35.059298
# Registering a LLMChatInProgressEvent event at time: 2025-08-21 11:47:35.118481
# Registering a LLMChatEndEvent event at time: 2025-08-21 11:47:35.121900
# WARNING:opentelemetry.sdk.trace:Setting attribute on ended span.
# Preparing to end span FunctionAgent.run_agent_step-eb86d0e9-195a-4202-a8c9-55d35b3d0048 at time: 2025-08-21 11:47:35.122754
# Emitting span FunctionAgent.parse_agent_output-a1f01130-d576-46b8-a771-83d3cb365f7f at time: 2025-08-21 11:47:35.123792
# Preparing to end span FunctionAgent.parse_agent_output-a1f01130-d576-46b8-a771-83d3cb365f7f at time: 2025-08-21 11:47:35.125237
# Emitting span FunctionAgent._done-82e42161-8b51-4815-9b65-565b9472452e at time: 2025-08-21 11:47:35.126046
# Registering a SpanDropEvent event at time: 2025-08-21 11:47:35.126367
# Preparing to exit span FunctionAgent._done-82e42161-8b51-4815-9b65-565b9472452e with an error at time: 2025-08-21 11:47:35.126561
# WARNING:opentelemetry.sdk.trace:Setting attribute on ended span.
# Preparing to end span FunctionAgent.run-55643190-156a-43f0-a33c-b7fe18adf3e7 at time: 2025-08-21 11:47:35.127851
# Result: Therefore, the result of (121 + 2) * 5 is 615.
# INFO:__main__:Session context for 'session-1234' detached

# %% [markdown]
# ## 8. Gen AI Observability Dashboard Understanding the Traces in AWS CloudWatch
#
# Once your LlamaIndex agent runs with OpenTelemetry instrumentation, you can visualize and analyze the traces in AWS CloudWatch's GenAI Observability dashboard. Navigate to Bedrock Agentcore and click on the Agent you just created.
#
# #### Sessions View Page:
#
# ![llama_index_sessions.png](images/llama_index_sessions.png)
#
#
# #### Trace View Page:
# Trace View:
#
# ![llama_index_sessions.png](images/llama_index_traces.png)
#
#
# Trace details:
#
# ![llama_index_sessions.png](images/llama_index_trace_details.png)

# %% [markdown]
# ## 9. Troubleshooting
#
# If you're not seeing traces in Amazon CloudWatch or X-Ray, check the following:
#
# 1. **AWS Credentials**: Ensure your AWS credentials are properly configured
# 2. **IAM Permissions**: Make sure your IAM user/role has permissions for CloudWatch
# 3. **Region**: Confirm you're looking in the correct AWS region
# 4. **Environment Variables**: Verify all OTEL_* environment variables are set correctly

# %% [markdown]
# ## 10. Conclusion
#
# Congratulations you implemented and instrumented a LlamaIndex Agent with Amazon Bedrock Model which has observability through Amazon CloudWatch.
#
# - LlamaIndex arithmetic agent.
# - Full OpenTelemetry tracing
# - Traces for Amazon Bedrock calls, LlamaIndex operations, etc.
# - Service name: agentic-llamaindex-agentcore

# %% [markdown]
# ## 11. Next Steps
#
# Now that you have LlamaIndex with OpenTelemetry set up, you can:
#
# 1. **Add More Agents**: Create a multi-agent architectures with different patterns
# 2. **Add Tools to your agent**: Integrate search tools, API tools, or custom tools
# 3. **[Set Up Alarms](https://docs.aws.amazon.com/AmazonCloudWatch/latest/monitoring/AlarmThatSendsEmail.html)**: Create alarms on the metrics that are important to your business like `latency`, `token input`, and `token output` etc..
